# %%
from fe_gmx.utils import XVG, AWH_LOG, AWH_2D_XVG, AWH_3D_XVG, AWH_DHDL

# %%
awh_3d_file = AWH_3D_XVG('data/awh_3d.xvg')
# Out:
# (105294, 9)

# %%
awh_3d_file.data
# Out:
#         dim_1  dim_2  dim_3    dim_4     dim_5  dim_6     dim_7  dim_8  \
# 0         2.2    0.0    0.0  158.721   84.1507    0.0  4.820640      1
# 1         2.2    0.0    4.0  158.721   83.9115    0.0  5.382020      1
# 2         2.2    0.0    8.0  158.721   82.5735    0.0  4.046950      1
# 3         2.2    0.0   12.0  158.721   81.2362    0.0  3.848420      1
# 4         2.2    0.0   16.0  158.721   80.7284    0.0  3.644450      1
# ...       ...    ...    ...      ...       ...    ...       ...    ...
# 105289    6.0   20.0  164.0  158.721  158.6030    0.0  0.000073      1
# 105290    6.0   20.0  168.0  158.721  158.6030    0.0  0.000021      1
# 105291    6.0   20.0  172.0  158.721  158.5920    0.0  0.000009      1
# 105292    6.0   20.0  176.0  158.721  158.4480    0.0  0.000006      1
# 105293    6.0   20.0  180.0  158.721  157.7050    0.0  0.000003      1
#
#            dim_9
# 0       0.063184
# 1       0.006606
# 2       0.150216
# 3       0.580416
# 4       1.690340
# ...

# %%
xvg_file = XVG('data/pullf.xvg')

# %%
awh_2d_file = AWH_2D_XVG('data/awh.xvg')

# %%
awh_2d_kT_file = AWH_2D_XVG('data/awh_kT.xvg')

# %%
log_file = AWH_LOG('data/awh.log')

# %%
import matplotlib.pyplot as plt
plt.plot(log_file.lambda_components[::20])

# %%
log_file.out_of_initial_stage_time
# Out:
# 15200

# %%
dhdl_file = AWH_DHDL('data/dhdl.xvg')

# %%
dhdl_file.data
# Out:
#    dim_1  dim_2       dim_3       dim_4       dim_5       dim_6       dim_7  \
# 0    0.0     20 -210.421650 -187.791020 -182.578830 -175.668590 -167.852480
# 1  200.0      0 -253.395720    0.000000   11.642282   21.831103   31.208966
# 2  400.0      2  -11.328918   17.275914    2.147025    0.000000    2.113825
# 3  600.0      0    0.533142    0.000000    2.506219    7.683383   14.030515
# 4  800.0      7  -83.150070  112.439550   49.433339   19.984802    5.042720
#
#         dim_8       dim_9      dim_10  ...      dim_16      dim_17  \
# 0 -159.463280 -150.667310 -141.560310  ...  -82.973805  -72.796008
# 1   40.125266   48.777084   57.278474  ...  107.602820  116.029340
# 2    6.305988   11.764645   18.098006  ...   65.854439   74.743196
# 3   21.023856   28.434296   36.140161  ...   85.727740   94.313550
# 4   -2.024446   -4.249075   -3.253764  ...   34.299629   43.152858
#
#        dim_18      dim_19      dim_20      dim_21      dim_22      dim_23  \
# ...
